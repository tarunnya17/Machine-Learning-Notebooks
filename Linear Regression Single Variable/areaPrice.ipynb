# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.5.3-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\iamna\appdata\roaming\python\python313\site-packages (from pandas) (2026.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.8 MB 4.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.8 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.8 MB 4.7 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.8 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.8 MB 5.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 5.8 MB/s eta 0:00:00
# Downloading numpy-2.5.3-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.6 MB 4.7 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.6 MB 4.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.6 MB 4.1 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.6 MB 4.1 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.6 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.6 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/12.6 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.6 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.6 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.6 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 3.9 MB/s eta 0:00:00
# Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.3 MB 5.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.3 MB 4.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.3 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.3 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.3 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.8 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.64.0-cp313-cp313-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --------------------- ------------------ 1.3/2.5 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 4.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp313-cp313-win_amd64.whl (70 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.2 MB 5.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.2 MB 4.6 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.2 MB 4.3 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.2/7.2 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.9 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 kiwisolver-1.5.1 matplotlib-3.11.1 numpy-2.5.3 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\iamna\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\iamna\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\iamna\appdata\roaming\python\python313\site-packages (3.0.5)
# Requirement already satisfied: numpy in c:\users\iamna\appdata\roaming\python\python313\site-packages (2.5.3)
# Requirement already satisfied: matplotlib in c:\users\iamna\appdata\roaming\python\python313\site-packages (3.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\iamna\appdata\roaming\python\python313\site-packages (from pandas) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn import linear_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\iamna\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.5.3)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.18.1-cp313-cp313-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.2 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.2 MB 8.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.2 MB 8.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 9.1 MB/s eta 0:00:00
# Downloading joblib-1.6.0-py3-none-any.whl (306 kB)
# Downloading narwhals-2.26.0-py3-none-any.whl (474 kB)
# Downloading scipy-1.18.1-cp313-cp313-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.6 MB 4.3 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/36.6 MB 4.1 MB/s eta 0:00:09
#    -- ------------------------------------- 2.6/36.6 MB 4.0 MB/s eta 0:00:09
#    --- ------------------------------------ 3.4/36.6 MB 3.9 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.2/36.6 MB 3.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.0/36.6 MB 3.9 MB/s eta 0:00:09
#    ------ --------------------------------- 5.8/36.6 MB 3.9 MB/s eta 0:00:08
#    ------- -------------------------------- 6.6/36.6 MB 3.9 MB/s eta 0:00:08
#    -------- ------------------------------- 7.3/36.6 MB 3.9 MB/s eta 0:00:08
#    -------- ------------------------------- 8.1/36.6 MB 3.9 MB/s eta 0:00:08
#    --------- ------------------------------ 8.9/36.6 MB 3.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 9.7/36.6 MB 3.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 10.5/36.6 MB 3.9 MB/s eta 0:00:07
#    ------------ --------------------------- 11.3/36.6 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 12.1/36.6 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 12.8/36.6 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.6/36.6 MB 3.8 MB/s eta 0:00:06
#    --------------- ------------------------ 14.4/36.6 MB 3.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 15.2/36.6 MB 3.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 15.7/36.6 MB 3.8 MB/s eta 0:00:06
#    ------------------ --------------------- 16.8/36.6 MB 3.8 MB/s eta 0:00:06
#    ------------------- -------------------- 17.6/36.6 MB 3.8 MB/s eta 0:00:05
#    ------------------- -------------------- 18.1/36.6 MB 3.8 MB/s eta 0:00:05
#    --------------------- ------------------ 19.4/36.6 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 20.2/36.6 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.0/36.6 MB 3.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 21.8/36.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------ --------------- 22.5/36.6 MB 3.8 MB/s eta 0:00:04
#    ------------------------- -------------- 23.3/36.6 MB 3.8 MB/s eta 0:00:04
#    -------------------------- ------------- 24.1/36.6 MB 3.8 MB/s eta 0:00:04
#    --------------------------- ------------ 24.9/36.6 MB 3.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 26.0/36.6 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 26.7/36.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 27.5/36.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 28.3/36.6 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 29.1/36.6 MB 3.8 MB/s eta 0:00:02
#    -------------------------------- ------- 29.9/36.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 30.9/36.6 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 31.7/36.6 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.6 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 33.3/36.6 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 34.1/36.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 34.9/36.6 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 3.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, cloudpickle, joblib, scikit-learn
# Successfully installed cloudpickle-3.1.2 joblib-1.6.0 narwhals-2.26.0 scikit-learn-1.9.0 scipy-1.18.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn import linear_model

# %%
df = pd.read_csv("Area_price.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\iamna\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# %matplotlib inline
plt.xlabel('area', fontsize=20)
plt.ylabel('price',fontsize=20)
plt.scatter(df.area, df.price, color = 'red', marker = '+')
plt.plot(df.area, reg.predict(df[['area']]),color='blue')

# %%
d = pd.read_csv("areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['prices'] = p #new column in dataframe and assign p
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("prediction.csv")
